# %%
# EDA Packages
import pandas as pd
import numpy as np
# Visualization Packages
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_d5c5dce290c74c90af5791572ad11e63 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='IrSG7vclg5MI69k7yQjlO3GzrOirkWudfXpZ-GYKSRKd',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.eu-geo.objectstorage.service.networklayer.com')

body = client_d5c5dce290c74c90af5791572ad11e63.get_object(Bucket='lifeexpectancy-donotdelete-pr-afg0kpb8iikmcf',Key='datasets_12603_17232_Life Expectancy Data (1).csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df = pd.read_csv(body)
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01                  71.280         65.0      1154  ...
# 1             64     0.01                  73.524         62.0       492  ...
# 2             66     0.01                  73.219         64.0       430  ...
# 3             69     0.01                  78.184         67.0      2787  ...
# 4             71     0.01                   7.097         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS      GDP  Population  \
# ...

# %%
# Descriptive Statistics
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01                  71.280         65.0      1154  ...
# 1             64     0.01                  73.524         62.0       492  ...
# 2             66     0.01                  73.219         64.0       430  ...
# 3             69     0.01                  78.184         67.0      2787  ...
# 4             71     0.01                   7.097         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS      GDP  Population  \
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
df.shape
# Out:
# (2938, 22)

# %%
df.describe()
# Out:
#            Year  Life expectancy   Adult Mortality  infant deaths   Alcohol  \
# count  2938.000          2928.000         2928.000       2938.000  2744.000
# mean   2007.519            69.225          164.796         30.304     4.603
# std       4.614             9.524          124.292        117.927     4.052
# min    2000.000            36.300            1.000          0.000     0.010
# 25%    2004.000            63.100           74.000          0.000     0.878
# 50%    2008.000            72.100          144.000          3.000     3.755
# 75%    2012.000            75.700          228.000         22.000     7.703
# max    2015.000            89.000          723.000       1800.000    17.870
#
#        percentage expenditure  Hepatitis B    Measles       BMI   \
# count                2938.000      2385.00    2938.000  2904.000
# mean                  738.251        80.94    2419.592    38.321
# std                  1987.915        25.07   11467.272    20.044
# ...

# %%
df.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# ...

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df.shape
# Out:
# (2938, 22)

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (1649, 22)

# %%
# Correlation Between Attributes using Pearson Correlation
df.corr(method='pearson')
# The correlation is Using only the float(numeric instead of all) hence we need to convert all to numeric not objects
# Out:
#                                   Year  Life expectancy   Adult Mortality  \
# Year                             1.000             0.051           -0.037
# Life expectancy                  0.051             1.000           -0.703
# Adult Mortality                 -0.037            -0.703            1.000
# infant deaths                    0.008            -0.169            0.042
# Alcohol                         -0.113             0.403           -0.176
# percentage expenditure           0.070             0.410           -0.238
# Hepatitis B                      0.115             0.200           -0.105
# Measles                         -0.054            -0.069           -0.004
#  BMI                             0.006             0.542           -0.352
# under-five deaths                0.010            -0.192            0.060
# Polio                           -0.017             0.327           -0.200
# Total expenditure                0.059             0.175           -0.085
# ...

# %%
#One Hot Encoding Using get_dummies
df1 = df

# %%
pd.set_option('precision',3)
df1.corr()
# Out:
#                                   Year  Life expectancy   Adult Mortality  \
# Year                             1.000             0.051           -0.037
# Life expectancy                  0.051             1.000           -0.703
# Adult Mortality                 -0.037            -0.703            1.000
# infant deaths                    0.008            -0.169            0.042
# Alcohol                         -0.113             0.403           -0.176
# percentage expenditure           0.070             0.410           -0.238
# Hepatitis B                      0.115             0.200           -0.105
# Measles                         -0.054            -0.069           -0.004
#  BMI                             0.006             0.542           -0.352
# under-five deaths                0.010            -0.192            0.060
# Polio                           -0.017             0.327           -0.200
# Total expenditure                0.059             0.175           -0.085
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df1.corr(),annot=True)
plt.show()

# %%
df1.skew()
# Out:
# Year                               -0.200
# Life expectancy                    -0.629
# Adult Mortality                     1.276
# infant deaths                       8.477
# Alcohol                             0.663
# percentage expenditure              4.981
# Hepatitis B                        -1.793
# Measles                             7.958
#  BMI                               -0.234
# under-five deaths                   8.341
# Polio                              -2.360
# Total expenditure                   0.213
# Diphtheria                         -2.487
#  HIV/AIDS                           4.974
# GDP                                 4.517
# Population                         14.186
#  thinness  1-19 years               1.821
#  thinness 5-9 years                 1.867
# Income composition of resources    -1.155
# Schooling                          -0.128
# dtype: float64

# %%
# %matplotlib inline

# %%
# Histogram
plt.figure(figsize=(50,30))
df1.hist()
plt.show()

# %% [markdown]
# # Feature Selection
# SelectKBest
# Select the features with the strongest relationship with output
# Recursive Feature Elimination
# Identify which features contribute the most to predicting the target output

# %%
Xfeatures = df1.values[:,3:21]
Xfeatures.shape
# Out:
# (1649, 18)

# %%
Ylabel=df1.iloc[:,21:22].values
Ylabel=Ylabel.astype('int')
Ylabel.shape
# Out:
# (1649, 1)

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
# Using a model to check 
from sklearn.linear_model import LinearRegression
# Don't be confuse about the name it is a classification algorithm not a regression
modelLogit = LinearRegression()
skb = SelectKBest(score_func=chi2,k=4)
skbfit = skb.fit(Xfeatures,Ylabel)

# %%
skbfit.scores_
best_features = skbfit.transform(Xfeatures)

# %%
# Highest scores show the best features
print("Scores",skbfit.scores_)
# Out:
# Scores [1.03728095e+03 3.01069677e+04 5.60050910e+04 2.52784054e+03
#  1.98181361e+06 1.44750261e+03 2.20914265e+06 5.58832351e+03
#  8.26870026e+04 1.45749805e+03 1.25742587e+02 1.31168323e+03
#  3.13903790e+03 1.16982989e+07 1.08547536e+10 1.88554595e+03
#  1.75529644e+03 5.56596844e+01]

# %%
mybestscores = list(skbfit.scores_)
myfeaturenames =  ['Adult Mortality', 'infant deaths',
       'percentage expenditure', 'under-five deaths ', 'Total expenditure',
       'Diphtheria ', ' thinness  1-19 years', ' thinness 5-9 years',
       'Income composition of resources', 'Schooling', 'Hepatitis', 'Measles ',
       ' BMI ', ' HIV', 'GDP', 'Population', 'Alcohol', 'Polio']

# %%
for b,f in zip(mybestscores,myfeaturenames):
    print(f'"Feature":{f} => {b/100}')
# Out:
# "Feature":Adult Mortality => 10.37280951838739
# "Feature":infant deaths => 301.0696765365337
# "Feature":percentage expenditure => 560.0509103516475
# "Feature":under-five deaths  => 25.278405444412577
# "Feature":Total expenditure => 19818.13605988722
# "Feature":Diphtheria  => 14.475026056047966
# "Feature": thinness  1-19 years => 22091.426545281516
# "Feature": thinness 5-9 years => 55.88323509011376
# "Feature":Income composition of resources => 826.8700263868202
# "Feature":Schooling => 14.574980460393888
# "Feature":Hepatitis => 1.2574258687878987
# "Feature":Measles  => 13.116832315642178
# "Feature": BMI  => 31.390378973285774
# "Feature": HIV => 116982.98936098909
# "Feature":GDP => 108547535.8532736
# "Feature":Population => 18.855459450709926
# "Feature":Alcohol => 17.55296437567748
# "Feature":Polio => 0.5565968442810005

# %%
# Hence the highest feature scores are GDP,Population,Measles,HIV,AdultMortality,infantdeaths.

# %% [markdown]
# Using Recursive Feature Elimination to check which feature contribute the most to predicting the target results

# %%
from sklearn.feature_selection import RFE
rfe = RFE(modelLogit,3)
rfe_fit = rfe.fit(Xfeatures,Ylabel)
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
print("Number of Features",rfe_fit.n_features_)
print("Feature Names",list(df1.columns)[3:21])
print("Selected Features",rfe_fit.support_)
print("Features Ranking",rfe_fit.ranking_)
# Out:
# Number of Features 3
# Feature Names ['Life expectancy ', 'Adult Mortality', 'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years', ' thinness 5-9 years', 'Income composition of resources']
# Selected Features [ True False False  True False False False False False False False False
#  False False False False False  True]
# Features Ranking [ 1 11  8  1 13 10 15  6  9  7  3 12  2 14 16  4  5  1]

# %% [markdown]
# Feature Importance
# The larger the score the more important the feature or attribute
# ExtraTreesClassifier

# %%
from sklearn.ensemble import ExtraTreesClassifier
modelExtra = ExtraTreesClassifier()
modelExtra.fit(Xfeatures,Ylabel)
print(modelExtra.feature_importances_)
# Out:
# [0.06865314 0.04903844 0.05064322 0.07837015 0.04571723 0.04015158
#  0.02752576 0.07021707 0.06075813 0.04087527 0.05556792 0.0435088
#  0.03170702 0.04507714 0.03310242 0.06807785 0.06996975 0.12103911]
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   app.launch_new_instance()

# %%
myimportantfeature = list(modelExtra.feature_importances_)

# %%
for imp,mf in zip(myimportantfeature,myfeaturenames):
    print(f'"Feature":{mf} => {imp*100}')
# Out:
# "Feature":Adult Mortality => 6.865314095159433
# "Feature":infant deaths => 4.90384430871707
# "Feature":percentage expenditure => 5.064321626753686
# "Feature":under-five deaths  => 7.837014521799836
# "Feature":Total expenditure => 4.571722886413754
# "Feature":Diphtheria  => 4.015157778557586
# "Feature": thinness  1-19 years => 2.752575978013558
# "Feature": thinness 5-9 years => 7.021706657828619
# "Feature":Income composition of resources => 6.0758133681540105
# "Feature":Schooling => 4.087526790129457
# "Feature":Hepatitis => 5.556792121848668
# "Feature":Measles  => 4.350880224655262
# "Feature": BMI  => 3.1707019940620293
# "Feature": HIV => 4.507714475976883
# "Feature":GDP => 3.310241684641129
# "Feature":Population => 6.807785297710815
# "Feature":Alcohol => 6.996975446606088
# "Feature":Polio => 12.103910742972113

# %%
# Split Data set
from sklearn.model_selection import train_test_split
seed = 7 # used to enable randomness being reproducible
X_train,X_test,Y_train,Y_test = train_test_split(Xfeatures,Ylabel,test_size=0.33,random_state=7)

# %%
#using our LinearRegression
modelLogit.fit(X_train, Y_train)
result = modelLogit.score(X_test, Y_test)
print("Accuracy: ",result*100.0)
# Out:
# Accuracy:  72.2159047056245

# %%
predictions = modelLogit.predict(X_test)
plt.scatter(Y_test,predictions)

# %%
X_test
# Out:
# array([[73.6, 169.0, 0, ..., 2.2, 2.3, 0.81],
#        [64.7, 22.0, 0, ..., 6.9, 6.8, 0.521],
#        [67.4, 267.0, 5, ..., 2.7, 2.8, 0.7],
#        ...,
#        [49.1, 369.0, 81, ..., 9.3, 9.2, 0.48],
#        [77.6, 65.0, 0, ..., 13.8, 13.9, 0.675],
#        [73.0, 184.0, 2, ..., 1.6, 1.6, 0.675]], dtype=object)

# %%
X_predict = np.array([28,1500,34.85942671,2000,4.25,65,27.1,28,0.536,9.7,6,64185,13.9,0.3,792.259698,1161977719,1.37,66])

# %%
type(X_predict)
# Out:
# numpy.ndarray

# %%
X_predict.shape
# Out:
# (18,)

# %%
newX = X_predict.reshape(-1,18)

# %%
newX.shape
# Out:
# (1, 18)

# %%
print(modelLogit.predict(newX))
# Out:
# [[-38482881.99997141]]

# %%
from sklearn import metrics

# %%
print("MAE",metrics.mean_absolute_error(Y_test,predictions))
print("MSE",metrics.mean_squared_error(Y_test,predictions))
print("RMSE",np.sqrt(metrics.mean_squared_error(Y_test,predictions)))
# Out:
# MAE 1.107429688333764
# MSE 2.075199947251509
# RMSE 1.440555430121142

# %%
# using Cross Validation with KFold
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
# Using our LinearRegression
num_folds = 10
seed = 7
kfold = KFold(n_splits=num_folds, random_state=seed)
results = cross_val_score(modelLogit, Xfeatures, Ylabel, cv=kfold)
print(results)
print("Mean Accuracy:", results.mean()*100.0)
print("STD Accuracy:", results.std()*100.0)
# Out:
# [0.72350763 0.75006502 0.65827843 0.8329007  0.35216924 0.44870709
#  0.57066838 0.83766909 0.5534652  0.33191924]
# Mean Accuracy: 60.59350013392238
# STD Accuracy: 17.628098717434636

# %%
# !pip install watson_machine_learning_client

# %%
from watson_machine_learning_client import WatsonMachineLearningAPIClient

# %%
wml_credentials={
  "apikey": "wXCOPIhjil3cc0BC43xMVNtxO_ufrUy3TMVaiVhzbkpn",
  "iam_apikey_description": "Auto-generated for key 4ef0971e-fee5-4da6-a303-fca9efe48ede",
  "iam_apikey_name": "Service credentials-1",
  "iam_role_crn": "crn:v1:bluemix:public:iam::::serviceRole:Writer",
  "iam_serviceid_crn": "crn:v1:bluemix:public:iam-identity::a/32c06459d62a46549afb3d9b0ecf8b16::serviceid:ServiceId-dc6f4f78-7952-4722-b839-ad0d925389ad",
  "instance_id": "eae279ac-a45c-46ee-a4cf-a9c8ac9224bb",
  "url": "https://eu-gb.ml.cloud.ibm.com"
}

# %%
client=WatsonMachineLearningAPIClient(wml_credentials)

# %%
metadata = {
    client.repository.ModelMetaNames.NAME: 'LinearRegression',
    client.repository.ModelMetaNames.AUTHOR_NAME: 'Daithala Maneesh'
}

# %%
model_artifact = client.repository.store_model(modelLogit,meta_props=metadata)
